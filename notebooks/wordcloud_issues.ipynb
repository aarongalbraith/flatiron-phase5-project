# %%
import pandas as pd
import matplotlib.pyplot as plt
from unidecode import unidecode
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk import TweetTokenizer
import string
from wordcloud import WordCloud

# %%
wordcloud = WordCloud(
    width=600,
    height=400,
    colormap='Greens',
    collocations = True
)

# %%
reviews = [
    "I cannot fathom such an instance of impropriety.",
    "Surely as I stand before you I am an ogre first and an astronaut last."
]

# %%
reviews
# Out:
# ['I cannot fathom such an instance of impropriety.',
#  'Surely as I stand before you I am an ogre first and an astronaut last.']

# %%
tokens = nltk.word_tokenize(','.join(reviews))

# %%
tokens
# Out:
# ['I',
#  'can',
#  'not',
#  'fathom',
#  'such',
#  'an',
#  'instance',
#  'of',
#  'impropriety.',
#  ',',
#  'Surely',
#  'as',
#  'I',
#  'stand',
#  'before',
#  'you',
#  'I',
#  'am',
#  'an',
#  'ogre',
#  'first',
#  'and',
#  'an',
#  'astronaut',
#  'last',
#  '.']

# %%
# tokens needs to be a list of words

tokens_joined = ','.join(tokens)
tokens_joined
# Out:
# 'I,can,not,fathom,such,an,instance,of,impropriety.,,,Surely,as,I,stand,before,you,I,am,an,ogre,first,and,an,astronaut,last,.'

# %%
sample = 'dog,cat,mouse,dog,dog,dog'

# %%
# tokens_joined needs to look like the above

my_cloud = wordcloud.generate(sample)

# %%
plt.figure(figsize = (12, 15)) 
plt.imshow(wordcloud) 
plt.axis('off');
